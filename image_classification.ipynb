# %% [markdown]
# # Image Classification
# ### Is it a dog or a cat?

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# * Remove image formats that do not work
# * Delete all images that are less than 10KB

# %%
import cv2
import imghdr
import os

# %%
data_dir = 'data'
image_extentions = ['jpeg', 'png', 'jpg', 'bmp']

# %%
image_path = os.path.join('data','dogs','German-Shepherd-dog-Alsatian.jpg')
img = cv2.imread(image_path)

# %%
import matplotlib.pyplot as plt
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir,image_class)):
        image_path = os.path.join(data_dir,image_class,image)
        try:
            img = cv2.imread(image_path) # Check that we can load the image to OpenCV
            tip = imghdr.what(image_path) # Check for extention
            if tip not in image_extentions:
                print(f"Image '{image_path}' with extention '{tip}' is not in ext list {image_extentions}")

        except:
            pass
# Out:
# Image 'data\cats\1200px-Cat_November_2010-1a.jpg' with extention 'None' is not in ext list ['jpeg', 'png', 'jpg', 'bmp']
# Image 'data\cats\1200px-Domesticated_indoor_cat_WI.jpg' with extention 'None' is not in ext list ['jpeg', 'png', 'jpg', 'bmp']
# Image 'data\cats\Abyssinian-sorrel.jpg' with extention 'None' is not in ext list ['jpeg', 'png', 'jpg', 'bmp']
# Image 'data\cats\black-cat-back.jpg' with extention 'None' is not in ext list ['jpeg', 'png', 'jpg', 'bmp']
# Image 'data\cats\Cat-Age-Chart-Hero-Opt1.jpg' with extention 'webp' is not in ext list ['jpeg', 'png', 'jpg', 'bmp']
# Image 'data\cats\cat-home-441939.jpg' with extention 'None' is not in ext list ['jpeg', 'png', 'jpg', 'bmp']
# Image 'data\cats\cat-meowing.jpg' with extention 'webp' is not in ext list ['jpeg', 'png', 'jpg', 'bmp']
# Image 'data\cats\f6b06b632d5369a70e6fc0240ca005cbd9-bic-kitty-litter.2x.rsocial.w600.jpg' with extention 'None' is not in ext list ['jpeg', 'png', 'jpg', 'bmp']
# ...

# %%
dogs_path = os.path.join(data_dir, 'dogs')
cats_path = os.path.join(data_dir, 'cats')
# for file in os.listdir
